# %% [markdown]
# # Doogle

# %% [markdown]
# ### 1) Hospitals / Vaccines / Other Medical Requirements / Diseases and Advice
#
# ##### - Pet hospitals near you and open in case of emergency // return review of the hospitals at some point, or rank by user rating [(Google Maps API + whatever API gives us the google ranking)]
#
# ##### - Pet shops near you and open or not, ranked by user rating (Google Maps API + whatever API gives us the google ranking)
#
# ##### - Checklist for things like vaccines, pills for parasites, collars for fleas etc... and a place to input date of vaccinations and pills so we get back a date of when you have to do it again
#
# #### - List of common diseases from a credible source and you write whichever one you want to know more about and you get back a short paragraph explaining plus a link with more information

# %% [markdown]
# ### 2) Food, Treats, and Accessories
#
# ##### - Food calculator with the variables age, food, price // return 3-5 different foods and links to shops to order
#
# ##### - Food calculator with the variables age, food, price
#
# ##### - Treats: differentiation between healthy and more commercial treats // (see what kind of info we can find on health and make a recommendation)
#
# ##### - Accessories: Harnesses, Leaches, Collars, Clothes/Dresses (maybe return information on each of these categories, top 10 popular items for example etc..)

# %% [markdown]
# ### 3) Entertainment - Beaches / Parks / Music
#
# ##### - Which beaches allow to bring dogs
# ##### - Parks and dogparks near you
# ##### - Show which restaurants that allow dogs are near the beaches and parks/dog parks
# ##### - Music -> we'll make a playlist of soothing music for dogs

# %%
import googlemaps
import pandas as pd
import time
import geopy.distance


# Google Maps API

api_key = 'AIzaSyDhqY1U1q5WVGMord6QXlw8ZcgwaamvRbQ'

map_client = googlemaps.Client(api_key)

# %%
my_address = input() ## write the address you are at

address_response = map_client.geocode(my_address) ## fetches the address 

my_address_coordinates = tuple(address_response[0]['geometry']['location'].values()) ## gets the tuple of the coordinates

my_radius = (int(input("Please enter a radius in kms")))*1000

response = map_client.places_nearby(location = my_address_coordinates, keyword = 'hospital veterinario', radius = my_radius) ## radius variable make user input


## fetching info with the keywords . radius was set to 10000m, might make it dynamic

# %%
response.keys() ## checking the keys, select results
# Out:
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
results_df = pd.DataFrame(response['results']) ## dataframe with results

# %%
results_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': 38.7146413, 'lng': -9.153...
# 1      OPERATIONAL  {'location': {'lat': 38.7117823, 'lng': -9.214...
# 2      OPERATIONAL  {'location': {'lat': 38.7357422, 'lng': -9.141...
# 3      OPERATIONAL  {'location': {'lat': 38.7588247, 'lng': -9.138...
# 4      OPERATIONAL  {'location': {'lat': 38.7622227, 'lng': -9.177...
# 5      OPERATIONAL  {'location': {'lat': 38.7775658, 'lng': -9.095...
# 6      OPERATIONAL  {'location': {'lat': 38.6709516, 'lng': -9.160...
# 7      OPERATIONAL  {'location': {'lat': 38.739302, 'lng': -9.1520...
# 8      OPERATIONAL  {'location': {'lat': 38.6500905, 'lng': -9.055...
# 9      OPERATIONAL  {'location': {'lat': 38.7346575, 'lng': -9.220...
# 10     OPERATIONAL  {'location': {'lat': 38.7522907, 'lng': -9.172...
# 11     OPERATIONAL  {'location': {'lat': 38.6405151, 'lng': -9.175...
# 12     OPERATIONAL  {'location': {'lat': 38.6981155, 'lng': -9.225...
# 13     OPERATIONAL  {'location': {'lat': 38.7312837, 'lng': -9.142...
# 14     OPERATIONAL  {'location': {'lat': 38.73422679999999, 'lng':...
# 15     OPERATIONAL  {'location': {'lat': 38.7400562, 'lng': -9.128...
# 16     OPERATIONAL  {'location': {'lat': 38.7426026, 'lng': -9.137...
# 17     OPERATIONAL  {'location': {'lat': 38.6209333, 'lng': -9.197...
# 18     OPERATIONAL  {'location': {'lat': 38.7074602, 'lng': -9.225...
# 19     OPERATIONAL  {'location': {'lat': 38.7580274, 'lng': -9.140...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                            name       opening_hours  \
# 0             Hospital Veterinário de São Bento  {'open_now': True}
# 1                   Veterinary Hospital Restelo  {'open_now': True}
# 2          Hospital Veterinário do Arco do Cego  {'open_now': True}
# 3               Veterinary Hospital de Alvalade  {'open_now': True}
# 4                Hospital Veterinário de Lisboa  {'open_now': True}
# 5               Bichomix - Hospital Veterinário  {'open_now': True}
# 6                   Hospital Veterinário SOSVET  {'open_now': True}
# 7             Onevet Hospital Veterinário Berna  {'open_now': True}
# 8               Sul do Tejo Veterinary Hospital  {'open_now': True}
# 9                   pET24 | Veterinary Hospital  {'open_now': True}
# 10              Laranjeiras Veterinary Hospital  {'open_now': True}
# 11                    GHV - Veterinary Hospital  {'open_now': True}
# 12                                 Cat Hospital  {'open_now': True}
# 13            Hospital Veterinário da Estefânia  {'open_now': True}
# 14          Associação Zoófila Portuguesa (AZP)  {'open_now': True}
# 15           IMV - Instituto Médico Veterinário  {'open_now': True}
# 16        Clínica Veterinária João XXI - Lisboa  {'open_now': True}
# 17  Main Veterinary Hospital Dr. Cristina Alves  {'open_now': True}
# 18         Clínica Veterinária João XXI - Algés  {'open_now': True}
# 19    Vetebrasil-clínica Médico Veterinária Lda  {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 2736, 'html_attributions': ['<a hr...
# 1   [{'height': 2832, 'html_attributions': ['<a hr...
# 2   [{'height': 5120, 'html_attributions': ['<a hr...
# 3   [{'height': 3120, 'html_attributions': ['<a hr...
# 4   [{'height': 2736, 'html_attributions': ['<a hr...
# 5   [{'height': 2000, 'html_attributions': ['<a hr...
# 6   [{'height': 3264, 'html_attributions': ['<a hr...
# 7   [{'height': 5504, 'html_attributions': ['<a hr...
# 8   [{'height': 4000, 'html_attributions': ['<a hr...
# 9   [{'height': 4032, 'html_attributions': ['<a hr...
# 10  [{'height': 4000, 'html_attributions': ['<a hr...
# 11  [{'height': 2135, 'html_attributions': ['<a hr...
# 12  [{'height': 4032, 'html_attributions': ['<a hr...
# 13  [{'height': 4032, 'html_attributions': ['<a hr...
# 14  [{'height': 4480, 'html_attributions': ['<a hr...
# 15  [{'height': 4128, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 744, 'html_attributions': ['<a hre...
# 18  [{'height': 4032, 'html_attributions': ['<a hr...
# 19  [{'height': 2592, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJgR3-_3wzGQ0RoabGjcn2SJc
# 1   ChIJjcgAOZ_MHg0RfjAro3aZqVo
# 2   ChIJwUKovaEzGQ0RYKK8C1kR44s
# 3   ChIJpQ2wwFMyGQ0RB5W1XzTKEkM
# 4   ChIJk6EwS8UyGQ0RFmkTVgsdxTM
# 5   ChIJAyLhQ38xGQ0Rw9jIarZ2kXo
# 6   ChIJKV9UEuI0GQ0RQaLaY2GGwr8
# 7   ChIJa31guQ4zGQ0RHJ8vpHSx52s
# 8   ChIJEdpCyPtJGQ0RVp5VgzVtN44
# 9   ChIJs3IJOO7MHg0RuTxOtI8KFFg
# 10  ChIJqT5wVt8yGQ0Re66z-7EmppI
# 11  ChIJC__9WEQ1GQ0RwrRNE_EZ9OU
# 12  ChIJeaEh7XrLHg0Rv4sundmmf2U
# 13  ChIJxw9a_Z4zGQ0RDwJCRAFd9I8
# 14  ChIJW49j8wszGQ0Rd6gulnr4mzI
# 15  ChIJX8J4s74zGQ0REnhWVjuFC5E
# 16  ChIJV-muB6UzGQ0R6_5K9E56p18
# 17  ChIJnRAyyVa1Hg0Rc0M7FxU7EW4
# 18  ChIJpRctjoLMHg0R06esAbfUUWE
# 19  ChIJ1_9_elQyGQ0Rs_omQ-jolOw
#
#                                             plus_code  rating  \
# 0   {'compound_code': 'PR7W+VG Lisbon', 'global_co...     4.7
# 1   {'compound_code': 'PQ6P+M9 Lisbon', 'global_co...     4.5
# 2   {'compound_code': 'PVP5+89 Lisbon', 'global_co...     4.5
# 3   {'compound_code': 'QV56+GJ Lisbon', 'global_co...     4.6
# 4   {'compound_code': 'QR6C+WW Lisbon', 'global_co...     4.2
# 5   {'compound_code': 'QWH3+2X Lisbon', 'global_co...     4.5
# 6   {'compound_code': 'MRCQ+9J Almada', 'global_co...     4.4
# 7   {'compound_code': 'PRQX+P5 Lisbon', 'global_co...     4.4
# 8   {'compound_code': 'MW2V+2M Barreiro', 'global_...     4.3
# 9   {'compound_code': 'PQMH+VP Amadora', 'global_c...     4.0
# 10  {'compound_code': 'QR2G+WR Lisbon', 'global_co...     4.2
# 11  {'compound_code': 'JRRF+5W Sobreda', 'global_c...     3.9
# 12  {'compound_code': 'MQXF+6J Lisbon', 'global_co...     4.4
# 13  {'compound_code': 'PVJ5+G4 Lisbon', 'global_co...     4.3
# 14  {'compound_code': 'PVM2+M3 Lisbon', 'global_co...     4.5
# 15  {'compound_code': 'PVRC+2Q Lisbon', 'global_co...     4.5
# 16  {'compound_code': 'PVV7+25 Lisbon', 'global_co...     4.6
# 17  {'compound_code': 'JRC3+95 Charneca de Caparic...     4.5
# 18  {'compound_code': 'PQ4F+XW Algés', 'global_cod...     4.6
# 19  {'compound_code': 'QV55+6Q Lisbon', 'global_co...     4.8
#
#                       reference   scope  \
# 0   ChIJgR3-_3wzGQ0RoabGjcn2SJc  GOOGLE
# 1   ChIJjcgAOZ_MHg0RfjAro3aZqVo  GOOGLE
# 2   ChIJwUKovaEzGQ0RYKK8C1kR44s  GOOGLE
# 3   ChIJpQ2wwFMyGQ0RB5W1XzTKEkM  GOOGLE
# 4   ChIJk6EwS8UyGQ0RFmkTVgsdxTM  GOOGLE
# 5   ChIJAyLhQ38xGQ0Rw9jIarZ2kXo  GOOGLE
# 6   ChIJKV9UEuI0GQ0RQaLaY2GGwr8  GOOGLE
# 7   ChIJa31guQ4zGQ0RHJ8vpHSx52s  GOOGLE
# 8   ChIJEdpCyPtJGQ0RVp5VgzVtN44  GOOGLE
# 9   ChIJs3IJOO7MHg0RuTxOtI8KFFg  GOOGLE
# 10  ChIJqT5wVt8yGQ0Re66z-7EmppI  GOOGLE
# 11  ChIJC__9WEQ1GQ0RwrRNE_EZ9OU  GOOGLE
# 12  ChIJeaEh7XrLHg0Rv4sundmmf2U  GOOGLE
# 13  ChIJxw9a_Z4zGQ0RDwJCRAFd9I8  GOOGLE
# 14  ChIJW49j8wszGQ0Rd6gulnr4mzI  GOOGLE
# 15  ChIJX8J4s74zGQ0REnhWVjuFC5E  GOOGLE
# 16  ChIJV-muB6UzGQ0R6_5K9E56p18  GOOGLE
# 17  ChIJnRAyyVa1Hg0Rc0M7FxU7EW4  GOOGLE
# 18  ChIJpRctjoLMHg0R06esAbfUUWE  GOOGLE
# 19  ChIJ1_9_elQyGQ0Rs_omQ-jolOw  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [veterinary_care, point_of_interest, establish...                 668
# 1   [veterinary_care, point_of_interest, establish...                1691
# 2   [veterinary_care, point_of_interest, establish...                 611
# 3   [veterinary_care, point_of_interest, establish...                 245
# 4   [veterinary_care, point_of_interest, establish...                 340
# 5   [veterinary_care, store, point_of_interest, es...                 553
# 6   [veterinary_care, point_of_interest, establish...                 545
# 7   [veterinary_care, point_of_interest, establish...                 486
# 8   [veterinary_care, point_of_interest, establish...                 449
# 9   [veterinary_care, point_of_interest, establish...                  92
# 10  [veterinary_care, point_of_interest, establish...                 473
# 11  [veterinary_care, pet_store, store, point_of_i...                 925
# 12  [veterinary_care, point_of_interest, establish...                 693
# 13  [veterinary_care, point_of_interest, health, e...                 176
# 14  [veterinary_care, point_of_interest, establish...                1391
# 15  [veterinary_care, point_of_interest, establish...                  50
# 16  [veterinary_care, pet_store, store, point_of_i...                 333
# 17  [veterinary_care, point_of_interest, health, e...                  71
# 18  [veterinary_care, pet_store, store, point_of_i...                 139
# 19  [veterinary_care, point_of_interest, establish...                  23
#
#                                              vicinity
# 0                       R. de São Bento 358 a, Lisboa
# 1               R. Gregório Lopes 1513 Loja E, Lisboa
# 2             R. Dona Filipa de Vilhena 4E 4F, Lisboa
# 3             Avenida do Brasil 184, Cv, Loja, Lisboa
# 4   123, R. Manuel Rodrigues da Silva 2 B / C, Lisboa
# 5                     Alameda dos Oceanos 85B, Lisboa
# 6                    R. Pedro Matos Filipe 1A, Almada
# 7                            Av. de Berna 35A, Lisboa
# 8                     R. Manuel Vasques 10B, Barreiro
# 9   Estrada de Alfragide, Edifícios Mirante, Lote ...
# 10                  R. São Tomás de Aquino 8C, Lisboa
# 11               R. Gen. Humberto Delgado 81, Sobreda
# 12                  R. Fernão Mendes Pinto 56, Lisboa
# 13                       R. Alm. Barroso 17 A, Lisboa
# 14                         Av. Luís Bívar 85C, Lisboa
# 15                        Av. Afonso Costa 36, Lisboa
# 16                          Av. João XXI 18 B, Lisboa
# 17                 R. Alagoa 26, Charneca de Caparica
# 18      Av. Bombeiros Voluntários de Algés 76B, Algés
# 19                      Av. Rio de Janeiro 66, Lisboa

# %%
## focus on hospitals, shops, parks

## webscrape one online shop for an online option when we return the shops


## create a database where we can store information from our pets for the vaccines and stuff
## user input information from dogs and we store it in variables.. age, photo, weight etc

# %%
# EXTRA!!
# entry_1 = tuple(vet_df['geometry'][0]['location'].values()) ## getting the lat and long values from the first entry of dataframe vet_df

# %%
# 
# print(geopy.distance.geodesic(my_address_coordinates, entry_1)) ## returns the distance between your location and the datapoint

## this doesn't consider mode of transport, just a straight line from one place to another
