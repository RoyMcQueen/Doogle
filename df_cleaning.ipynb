# %%
import pandas as pd
import numpy as np

# %%
dog_park_df = pd.read_csv('datasets/dog_park_df.csv')
# Out:
#     Unnamed: 0 business_status  \
# 0            0     OPERATIONAL
# 1            1     OPERATIONAL
# 2            2     OPERATIONAL
# 3            3     OPERATIONAL
# 4            4     OPERATIONAL
# 5            5     OPERATIONAL
# 6            6     OPERATIONAL
# 7            7     OPERATIONAL
# 8            8     OPERATIONAL
# 9            9     OPERATIONAL
# 10          10     OPERATIONAL
# 11          11     OPERATIONAL
# 12          12     OPERATIONAL
# 13          13     OPERATIONAL
# 14          14     OPERATIONAL
# 15          15     OPERATIONAL
# 16          16     OPERATIONAL
#
#                                              geometry  \
# 0   {'location': {'lat': 38.7524415, 'lng': -9.177...
# 1   {'location': {'lat': 38.7395869, 'lng': -9.137...
# 2   {'location': {'lat': 38.7217101, 'lng': -9.139...
# 3   {'location': {'lat': 38.71469310000001, 'lng':...
# 4   {'location': {'lat': 38.754967, 'lng': -9.1524...
# 5   {'location': {'lat': 38.7126413, 'lng': -9.131...
# 6   {'location': {'lat': 38.7544488, 'lng': -9.094...
# 7   {'location': {'lat': 38.7214004, 'lng': -9.156...
# 8   {'location': {'lat': 38.7481949, 'lng': -9.124...
# 9   {'location': {'lat': 38.7293201, 'lng': -9.123...
# 10  {'location': {'lat': 38.71603330000001, 'lng':...
# 11  {'location': {'lat': 38.7113793, 'lng': -9.154...
# 12  {'location': {'lat': 38.7434954, 'lng': -9.137...
# 13  {'location': {'lat': 38.7361957, 'lng': -9.142...
# 14  {'location': {'lat': 38.7485837, 'lng': -9.134...
# 15  {'location': {'lat': 38.7017574, 'lng': -9.182...
# 16  {'location': {'lat': 38.7296819, 'lng': -9.165...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #4DB546
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                        name  \
# 0                         Dog Park Bensaúde
# 1                                  Dog Park
# 2                             Parque Canino
# 3                Parque Canino dos Prazeres
# 4             Parque Canino do Campo Grande
# 5                  Animacão - Parque Canino
# 6                         Parque canino Sul
# 7     Parque Canino do Jardim das Amoreiras
# 8               Parque Canino da Bela Vista
# 9            Parque Canino Alto de São João
# 10                           Parque de cães
# 11                            Parque Canino
# 12                          Jardim dos cães
# 13  Parque Canino do Jardim do Arco do Cego
# 14                            Parque Canino
# 15             Parque Canino de Santo Amaro
# 16           Parque Canino (CC dos Mestres)
#
#                                                photos  \
# 0   [{'height': 2988, 'html_attributions': ['<a hr...
# 1   [{'height': 1816, 'html_attributions': ['<a hr...
# 2   [{'height': 3024, 'html_attributions': ['<a hr...
# 3   [{'height': 3024, 'html_attributions': ['<a hr...
# 4   [{'height': 2304, 'html_attributions': ['<a hr...
# 5   [{'height': 4032, 'html_attributions': ['<a hr...
# 6   [{'height': 3024, 'html_attributions': ['<a hr...
# 7   [{'height': 2552, 'html_attributions': ['<a hr...
# 8   [{'height': 1080, 'html_attributions': ['<a hr...
# 9   [{'height': 4000, 'html_attributions': ['<a hr...
# 10  [{'height': 3024, 'html_attributions': ['<a hr...
# 11  [{'height': 2016, 'html_attributions': ['<a hr...
# 12                                                NaN
# 13                                                NaN
# 14  [{'height': 3121, 'html_attributions': ['<a hr...
# 15  [{'height': 1836, 'html_attributions': ['<a hr...
# 16  [{'height': 1080, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJI7OjDdgyGQ0RkFshPNI6eOc
# 1   ChIJORo5dhUzGQ0RjxGOpC3Jt7Q
# 2   ChIJJz_fhIQzGQ0RMUxVdSYpHeI
# 3   ChIJdxbMQ14zGQ0RIru40fiS_78
# 4   ChIJUWS9lP0yGQ0RztrYdIa7Mcc
# 5   ChIJ52H7NIw1GQ0RM8F19GTGK3k
# 6   ChIJlYF2FmkxGQ0RAEveN80Pun8
# 7   ChIJn9LB06YzGQ0R0CDKNQrtsx8
# 8   ChIJHYxueRczGQ0RGc0KC9CL-vQ
# 9   ChIJQehVqYUzGQ0R2y9oe2Dr6VY
# 10  ChIJK-4EuQUzGQ0R32swHFXFYHo
# 11  ChIJm2M25mY1GQ0R7zm8NI3MDYc
# 12  ChIJZ0dtCaUzGQ0R8gMifYycTXo
# 13  ChIJkeR6qh8zGQ0RRKDlZGP_Rjg
# 14  ChIJuwQSjg4zGQ0ReKfps7RxOsk
# 15  ChIJPdAIixo1GQ0RrMgQ00QgqPY
# 16  ChIJ5X_MNUczGQ0RDDry3zyBJcw
#
#                                             plus_code  rating  \
# 0   {'compound_code': 'QR2C+XW Lisbon', 'global_co...     2.0
# 1   {'compound_code': 'PVQ6+RW Lisbon', 'global_co...     4.5
# 2   {'compound_code': 'PVC6+M5 Lisbon', 'global_co...     4.1
# 3   {'compound_code': 'PR7J+V5 Lisbon', 'global_co...     4.0
# 4   {'compound_code': 'QR3X+X2 Lisbon', 'global_co...     4.2
# 5   {'compound_code': 'PV79+3C Lisbon', 'global_co...     5.0
# 6   {'compound_code': 'QW34+Q5 Lisbon', 'global_co...     0.0
# 7   {'compound_code': 'PRCV+HG Lisbon', 'global_co...     4.0
# 8   {'compound_code': 'PVXG+76 Lisbon', 'global_co...     4.6
# 9   {'compound_code': 'PVHG+PP Lisbon', 'global_co...     3.8
# 10  {'compound_code': 'PV8G+C8 Lisbon', 'global_co...     0.0
# 11  {'compound_code': 'PR6W+H9 Lisbon', 'global_co...     5.0
# 12  {'compound_code': 'PVV7+92 Lisbon', 'global_co...     4.5
# 13  {'compound_code': 'PVP4+FV Lisbon', 'global_co...     2.0
# 14  {'compound_code': 'PVX8+C4 Lisbon', 'global_co...     4.2
# 15  {'compound_code': 'PR28+PW Lisbon', 'global_co...     1.0
# 16  {'compound_code': 'PRHM+VJ Lisbon', 'global_co...     4.0
#
#                       reference   scope  \
# 0   ChIJI7OjDdgyGQ0RkFshPNI6eOc  GOOGLE
# 1   ChIJORo5dhUzGQ0RjxGOpC3Jt7Q  GOOGLE
# 2   ChIJJz_fhIQzGQ0RMUxVdSYpHeI  GOOGLE
# 3   ChIJdxbMQ14zGQ0RIru40fiS_78  GOOGLE
# 4   ChIJUWS9lP0yGQ0RztrYdIa7Mcc  GOOGLE
# 5   ChIJ52H7NIw1GQ0RM8F19GTGK3k  GOOGLE
# 6   ChIJlYF2FmkxGQ0RAEveN80Pun8  GOOGLE
# 7   ChIJn9LB06YzGQ0R0CDKNQrtsx8  GOOGLE
# 8   ChIJHYxueRczGQ0RGc0KC9CL-vQ  GOOGLE
# 9   ChIJQehVqYUzGQ0R2y9oe2Dr6VY  GOOGLE
# 10  ChIJK-4EuQUzGQ0R32swHFXFYHo  GOOGLE
# 11  ChIJm2M25mY1GQ0R7zm8NI3MDYc  GOOGLE
# 12  ChIJZ0dtCaUzGQ0R8gMifYycTXo  GOOGLE
# 13  ChIJkeR6qh8zGQ0RRKDlZGP_Rjg  GOOGLE
# 14  ChIJuwQSjg4zGQ0ReKfps7RxOsk  GOOGLE
# 15  ChIJPdAIixo1GQ0RrMgQ00QgqPY  GOOGLE
# 16  ChIJ5X_MNUczGQ0RDDry3zyBJcw  GOOGLE
#
#                                              types  user_ratings_total  \
# 0   ['park', 'point_of_interest', 'establishment']                   4
# 1   ['park', 'point_of_interest', 'establishment']                  13
# 2   ['park', 'point_of_interest', 'establishment']                  33
# 3   ['park', 'point_of_interest', 'establishment']                  45
# 4   ['park', 'point_of_interest', 'establishment']                 936
# 5   ['park', 'point_of_interest', 'establishment']                  10
# 6   ['park', 'point_of_interest', 'establishment']                   0
# 7   ['park', 'point_of_interest', 'establishment']                   4
# 8   ['park', 'point_of_interest', 'establishment']                  14
# 9   ['park', 'point_of_interest', 'establishment']                  42
# 10  ['park', 'point_of_interest', 'establishment']                   0
# 11  ['park', 'point_of_interest', 'establishment']                   1
# 12  ['park', 'point_of_interest', 'establishment']                   2
# 13  ['park', 'point_of_interest', 'establishment']                   1
# 14  ['park', 'point_of_interest', 'establishment']                   9
# 15  ['park', 'point_of_interest', 'establishment']                   3
# 16  ['park', 'point_of_interest', 'establishment']                   2
#
#                                              vicinity       opening_hours
# 0                                              Lisbon                 NaN
# 1                          R. Brás Pacheco 5A, Lisboa                  {}
# 2                                              Lisbon  {'open_now': True}
# 3                    Praça São João Bosco 558, Lisboa  {'open_now': True}
# 4                                Campo Grande, Lisboa  {'open_now': True}
# 5                       Pátio de Dom Fradique, Lisboa  {'open_now': True}
# 6                  R. Nova dos Mercadores 301, Lisboa  {'open_now': True}
# 7                        Jardim das Amoreiras, Lisboa                 NaN
# 8            Av. Mal. António de Spinola 1950, Lisboa                 NaN
# 9                                          Parada, do                 NaN
# 10                   Campo de Santa Clara 151, Lisboa                  {}
# 11                       Av. Dom Carlos i 119, Lisboa  {'open_now': True}
# 12                   Jardim Fernando Pessa 16, Lisboa                 NaN
# 13                        Av. João Crisóstomo, Lisboa                  {}
# 14      Av. dos Estados Unidos da América 37A, Lisboa                 NaN
# 15  R. Academia Recreativa de Santo Amaro 7-46, Li...                 NaN
# 16                                             Lisbon                 NaN

# %%
dog_park_df.drop(['Unnamed: 0','geometry','icon','icon_background_color', 'icon_mask_base_uri','photos','place_id','plus_code','reference','scope','types','business_status'],axis = 1, inplace=True)

# %%
dog_park_df.rename(columns = {'name':'Dog_Park', 'rating':'User_Rating','user_ratings_total':'User_Rating_Total','vicinity':'Address','opening_hours':'Open Now'}, inplace = True)

# %%
dog_park_df
# Out:
#                                    Dog_Park  User_Rating  User_Rating_Total  \
# 0                         Dog Park Bensaúde          2.0                  4
# 1                                  Dog Park          4.5                 13
# 2                             Parque Canino          4.1                 33
# 3                Parque Canino dos Prazeres          4.0                 45
# 4             Parque Canino do Campo Grande          4.2                936
# 5                  Animacão - Parque Canino          5.0                 10
# 6                         Parque canino Sul          0.0                  0
# 7     Parque Canino do Jardim das Amoreiras          4.0                  4
# 8               Parque Canino da Bela Vista          4.6                 14
# 9            Parque Canino Alto de São João          3.8                 42
# 10                           Parque de cães          0.0                  0
# 11                            Parque Canino          5.0                  1
# 12                          Jardim dos cães          4.5                  2
# 13  Parque Canino do Jardim do Arco do Cego          2.0                  1
# 14                            Parque Canino          4.2                  9
# 15             Parque Canino de Santo Amaro          1.0                  3
# 16           Parque Canino (CC dos Mestres)          4.0                  2
#
#                                               Address            Open Now
# 0                                              Lisbon                 NaN
# 1                          R. Brás Pacheco 5A, Lisboa                  {}
# 2                                              Lisbon  {'open_now': True}
# 3                    Praça São João Bosco 558, Lisboa  {'open_now': True}
# 4                                Campo Grande, Lisboa  {'open_now': True}
# 5                       Pátio de Dom Fradique, Lisboa  {'open_now': True}
# 6                  R. Nova dos Mercadores 301, Lisboa  {'open_now': True}
# 7                        Jardim das Amoreiras, Lisboa                 NaN
# 8            Av. Mal. António de Spinola 1950, Lisboa                 NaN
# 9                                          Parada, do                 NaN
# 10                   Campo de Santa Clara 151, Lisboa                  {}
# 11                       Av. Dom Carlos i 119, Lisboa  {'open_now': True}
# 12                   Jardim Fernando Pessa 16, Lisboa                 NaN
# 13                        Av. João Crisóstomo, Lisboa                  {}
# 14      Av. dos Estados Unidos da América 37A, Lisboa                 NaN
# 15  R. Academia Recreativa de Santo Amaro 7-46, Li...                 NaN
# 16                                             Lisbon                 NaN

# %%
pet_shop_df = pd.read_csv('datasets/pet_shops_df.csv')

# %%
pet_shop_df.drop(['geometry','icon','icon_background_color', 'icon_mask_base_uri','photos','place_id','plus_code','reference','scope','types','business_status'],axis = 1, inplace=True)

# %%
pet_shop_df.rename(columns = {'name':'Pet_Shop', 'rating':'User_Rating','user_ratings_total':'User_Rating_Total','vicinity':'Address','opening_hours':'Open Now'}, inplace = True)

# %%
pet_shop_df.head()
# Out:
#              Pet_Shop            Open Now  User_Rating  User_Rating_Total  \
# 0             PETNESS  {'open_now': True}          3.9                595
# 1  Patudaria Pet Shop  {'open_now': True}          4.8                 50
# 2             Petblue  {'open_now': True}          4.8                 41
# 3             PetBelo  {'open_now': True}          5.0                 28
# 4        Pets & Pools  {'open_now': True}          4.4                 22
#
#                                       Address
# 0            Estrada do Zambujal 47A, Amadora
# 1             R. Bernardim Ribeiro 7A, Lisboa
# 2                   Rua Dom João V 31, Lisboa
# 3           Tv. de Santa Quitéria 69C, Lisboa
# 4  Avenida Afonso Costa 46C Lojas B/C, Lisboa

# %%
pet_shop_df.drop(['Open Now_'],axis = 1, inplace = True)

# %%
pet_shop_df
# Out:
#                       Pet_Shop            Open Now  User_Rating  \
# 0                      PETNESS  {'open_now': True}          3.9
# 1           Patudaria Pet Shop  {'open_now': True}          4.8
# 2                      Petblue  {'open_now': True}          4.8
# 3                      PetBelo  {'open_now': True}          5.0
# 4                 Pets & Pools  {'open_now': True}          4.4
# 5                   Dogs' Wish  {'open_now': True}          4.6
# 6             Buddy's Pet Shop  {'open_now': True}          4.8
# 7                   Pet Outlet  {'open_now': True}          4.4
# 8                  Perfect Pet  {'open_now': True}          4.4
# 9                   Wonder Dog  {'open_now': True}          5.0
# 10         Unidogs Petgrooming  {'open_now': True}          5.0
# 11            PETAjuda Petshop  {'open_now': True}          5.0
# 12     Doggie | Pet Shop 🐶 😻 🐾  {'open_now': True}          4.9
# 13                   Petblue 2  {'open_now': True}          5.0
# 14           PetOutlet-Benfica  {'open_now': True}          4.6
# 15          Aquário do Mirante  {'open_now': True}          4.4
# 16  Spazio Animal - Ameixoeira  {'open_now': True}          0.0
# 17           Tuacano & Bulldog                 NaN          0.0
# 18                    Pet Roma  {'open_now': True}          5.0
# 19                   Petracoes  {'open_now': True}          4.7
#
#     User_Rating_Total                                            Address
# 0                 595                   Estrada do Zambujal 47A, Amadora
# 1                  50                    R. Bernardim Ribeiro 7A, Lisboa
# 2                  41                          Rua Dom João V 31, Lisboa
# 3                  28                  Tv. de Santa Quitéria 69C, Lisboa
# 4                  22         Avenida Afonso Costa 46C Lojas B/C, Lisboa
# 5                 206  morada estacionamento, R. António Livramento 1...
# 6                  63                     R. Cidade da Beira 46J, Lisboa
# 7                 164                  R. dos Fanqueiros 210 212, Lisboa
# 8                  84                      Av. Infante Santo 56A, Lisboa
# 9                  14                  Tv. Henrique Cardoso 55 a, Lisboa
# 10                  6                R. António Lopes Ribeiro 7A, Lisboa
# 11                  2                Tv. da Boa Hora à Ajuda 30H, Lisboa
# 12                 41              Av. Óscar Monteiro Torres 29C, Lisboa
# 13                  1                   Av. Praia da Vitória 15A, Lisboa
# 14                125                      Estr. de Benfica 496A, Lisboa
# 15                 47                              R. Mirante 57, Lisboa
# 16                  0                           R. Jorge de Sena, Lisboa
# 17                  0             Praceta Eng. Alves da Costa 1, Amadora
# 18                  5                            Av. de Roma 87B, Lisboa
# 19                 35         Alameda Dom Afonso Henriques Nº11A, Lisboa

# %%
vet_hospital_df = pd.read_csv('datasets/veterinary_hospital_df.csv')
vet_hospital_df.drop(['Unnamed: 0','geometry','icon','icon_background_color', 'icon_mask_base_uri','photos','place_id','plus_code','reference','scope','types','business_status'],axis = 1, inplace=True)

# %%
vet_hospital_df.rename(columns = {'name':'Hospital_Name', 'rating':'User_Rating','user_ratings_total':'User_Rating_Total','vicinity':'Address','opening_hours':'Open Now'}, inplace = True)

# %%
vet_hospital_df.sort_values(by=['User_Rating','User_Rating_Total'], ascending=False)
# Out:
#                                   Hospital_Name            Open Now  \
# 19    Vetebrasil-clínica Médico Veterinária Lda  {'open_now': True}
# 0             Hospital Veterinário de São Bento  {'open_now': True}
# 16        Clínica Veterinária João XXI - Lisboa  {'open_now': True}
# 3               Veterinary Hospital de Alvalade  {'open_now': True}
# 18         Clínica Veterinária João XXI - Algés  {'open_now': True}
# 1                   Veterinary Hospital Restelo  {'open_now': True}
# 14          Associação Zoófila Portuguesa (AZP)  {'open_now': True}
# 2          Hospital Veterinário do Arco do Cego  {'open_now': True}
# 5               Bichomix - Hospital Veterinário  {'open_now': True}
# 17  Main Veterinary Hospital Dr. Cristina Alves  {'open_now': True}
# 15           IMV - Instituto Médico Veterinário  {'open_now': True}
# 12                                 Cat Hospital  {'open_now': True}
# 6                   Hospital Veterinário SOSVET  {'open_now': True}
# 7             Onevet Hospital Veterinário Berna  {'open_now': True}
# 8               Sul do Tejo Veterinary Hospital  {'open_now': True}
# 13            Hospital Veterinário da Estefânia  {'open_now': True}
# 10              Laranjeiras Veterinary Hospital  {'open_now': True}
# 4                Hospital Veterinário de Lisboa  {'open_now': True}
# 9                   pET24 | Veterinary Hospital  {'open_now': True}
# 11                    GHV - Veterinary Hospital  {'open_now': True}
#
#     User_Rating  User_Rating_Total  \
# 19          4.8                 23
# 0           4.7                668
# 16          4.6                333
# 3           4.6                245
# 18          4.6                139
# 1           4.5               1691
# 14          4.5               1391
# 2           4.5                611
# 5           4.5                553
# 17          4.5                 71
# 15          4.5                 50
# 12          4.4                693
# 6           4.4                545
# 7           4.4                486
# 8           4.3                449
# 13          4.3                176
# 10          4.2                473
# 4           4.2                340
# 9           4.0                 92
# 11          3.9                925
#
#                                               Address
# 19                      Av. Rio de Janeiro 66, Lisboa
# 0                       R. de São Bento 358 a, Lisboa
# 16                          Av. João XXI 18 B, Lisboa
# 3             Avenida do Brasil 184, Cv, Loja, Lisboa
# 18      Av. Bombeiros Voluntários de Algés 76B, Algés
# 1               R. Gregório Lopes 1513 Loja E, Lisboa
# 14                         Av. Luís Bívar 85C, Lisboa
# 2             R. Dona Filipa de Vilhena 4E 4F, Lisboa
# 5                     Alameda dos Oceanos 85B, Lisboa
# 17                 R. Alagoa 26, Charneca de Caparica
# 15                        Av. Afonso Costa 36, Lisboa
# 12                  R. Fernão Mendes Pinto 56, Lisboa
# 6                    R. Pedro Matos Filipe 1A, Almada
# 7                            Av. de Berna 35A, Lisboa
# 8                     R. Manuel Vasques 10B, Barreiro
# 13                       R. Alm. Barroso 17 A, Lisboa
# 10                  R. São Tomás de Aquino 8C, Lisboa
# 4   123, R. Manuel Rodrigues da Silva 2 B / C, Lisboa
# 9   Estrada de Alfragide, Edifícios Mirante, Lote ...
# 11               R. Gen. Humberto Delgado 81, Sobreda

# %%
vet_hospital_df[['Hospital_Name','User_Rating','User_Rating_Total','Address','Open Now']]
# Out:
#                                   Hospital_Name  User_Rating  \
# 0             Hospital Veterinário de São Bento          4.7
# 1                   Veterinary Hospital Restelo          4.5
# 2          Hospital Veterinário do Arco do Cego          4.5
# 3               Veterinary Hospital de Alvalade          4.6
# 4                Hospital Veterinário de Lisboa          4.2
# 5               Bichomix - Hospital Veterinário          4.5
# 6                   Hospital Veterinário SOSVET          4.4
# 7             Onevet Hospital Veterinário Berna          4.4
# 8               Sul do Tejo Veterinary Hospital          4.3
# 9                   pET24 | Veterinary Hospital          4.0
# 10              Laranjeiras Veterinary Hospital          4.2
# 11                    GHV - Veterinary Hospital          3.9
# 12                                 Cat Hospital          4.4
# 13            Hospital Veterinário da Estefânia          4.3
# 14          Associação Zoófila Portuguesa (AZP)          4.5
# 15           IMV - Instituto Médico Veterinário          4.5
# 16        Clínica Veterinária João XXI - Lisboa          4.6
# 17  Main Veterinary Hospital Dr. Cristina Alves          4.5
# 18         Clínica Veterinária João XXI - Algés          4.6
# 19    Vetebrasil-clínica Médico Veterinária Lda          4.8
#
#     User_Rating_Total                                            Address  \
# 0                 668                      R. de São Bento 358 a, Lisboa
# 1                1691              R. Gregório Lopes 1513 Loja E, Lisboa
# 2                 611            R. Dona Filipa de Vilhena 4E 4F, Lisboa
# 3                 245            Avenida do Brasil 184, Cv, Loja, Lisboa
# 4                 340  123, R. Manuel Rodrigues da Silva 2 B / C, Lisboa
# 5                 553                    Alameda dos Oceanos 85B, Lisboa
# 6                 545                   R. Pedro Matos Filipe 1A, Almada
# 7                 486                           Av. de Berna 35A, Lisboa
# 8                 449                    R. Manuel Vasques 10B, Barreiro
# 9                  92  Estrada de Alfragide, Edifícios Mirante, Lote ...
# 10                473                  R. São Tomás de Aquino 8C, Lisboa
# 11                925               R. Gen. Humberto Delgado 81, Sobreda
# 12                693                  R. Fernão Mendes Pinto 56, Lisboa
# 13                176                       R. Alm. Barroso 17 A, Lisboa
# 14               1391                         Av. Luís Bívar 85C, Lisboa
# 15                 50                        Av. Afonso Costa 36, Lisboa
# 16                333                          Av. João XXI 18 B, Lisboa
# 17                 71                 R. Alagoa 26, Charneca de Caparica
# 18                139      Av. Bombeiros Voluntários de Algés 76B, Algés
# 19                 23                      Av. Rio de Janeiro 66, Lisboa
#
#               Open Now
# 0   {'open_now': True}
# 1   {'open_now': True}
# 2   {'open_now': True}
# 3   {'open_now': True}
# 4   {'open_now': True}
# 5   {'open_now': True}
# 6   {'open_now': True}
# 7   {'open_now': True}
# 8   {'open_now': True}
# 9   {'open_now': True}
# 10  {'open_now': True}
# 11  {'open_now': True}
# 12  {'open_now': True}
# 13  {'open_now': True}
# 14  {'open_now': True}
# 15  {'open_now': True}
# 16  {'open_now': True}
# 17  {'open_now': True}
# 18  {'open_now': True}
# 19  {'open_now': True}

# %%
display()
